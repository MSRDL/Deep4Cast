# %% [markdown]
# # GRU with uncertainty tutorial

# %% [markdown]
# In this tutorial, we show how to quickly set up and train an RNN regression model with the deep4cast package. The goal is to show you how to handle the package interface and inspect the model object after training. The example data constitutes of a monthly 26-dimensional multivariate time series.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_table

from deep4cast.forecasters import Forecaster
import deep4cast.metrics as metrics

# %matplotlib inline

# Fix random number seed for reproducibility
np.random.seed(3)

# %% [markdown]
# ## Data preparation for single multivariate time series

# %% [markdown]
# Before we can fit a model we first have to load, clean, and prepare our dataset so that the model can accept it. The data is prepared such that the forecaster view the data as a single example of a 26-dimensional time series. In another example, further down, we will train a forecaster that understands the data as 26 examples for univariate time series.

# %%
# Load the data from file
filename = 'timeseries_data.csv'
df = read_table(filename, sep=',')

# Prepare the data set
data = df.values
data = np.expand_dims(data, 0)

# We just need a small holdout dataset for evaluation purposes
holdout = 9
train_data = data[:,:-9,:]
test_data = data[:,-9:,:]

# Plot the dataset
plt.figure(figsize=(10,5))
plt.plot(data[0,::-1,:], 'k')
plt.xlabel('Month before beginning')
plt.ylabel('Quantity')
# Out:
# Text(0,0.5,'Quantity')

# %% [markdown]
# ## Recurrent Neural Network Forecaster using GRU cells

# %% [markdown]
# Now that we have cleaned and prepared our dataset, we can proceed to fit a regression model. Here, we choose the LSTM-GRU, with windowed training intput.

# %%
topology = [
    {
        'meta': {
            'layer_type': 'GRU', 
            'layer_id': 'gru1', 
            'parent_ids': ['input']
        },
        'params': {
            'units': 32, 
            'activation': 'relu',
            'return_sequences': False
        }
    }
]

# %% [markdown]
# Now, we can set up the forecaster object using arguments to specify lookbacks and forecasting horizons, as well as optimizer parameters. The default loss of the forecaster is the mean-squared error loss.

# %%
forecaster = Forecaster(
    topology,
    lag=20,  # This is the number of time steps used to predict the future for each data point
    horizon=9,  # This is how many time steps into the future we want to produce
    optimizer='adam',  # Which optimizer the forecaster is using
    loss='heteroscedastic_gaussian',  # This specifies a custom log-likelihood loss
    lr=0.001,  # This is the learning rate for the optimizer
    dropout_rate=0.1,  # The dropout rate refers to the MC dropout rate applied after each layer
    max_epochs=100  # Maximum number of epochs that the optimizer will perform
)

# %% [markdown]
# We can now fit the forecaster and unspect the training and validation losses. The plot below show the training and validation loss for each epoch of training. By default, the forecaster uses Keras' early stopping callback to stopp training when the validation set error increases. The default holdout from the input data used for validation is 10% of the data.

# %%
forecaster.fit(train_data, val_frac=0.10, patience=50)  # patience is the number of epochs to wait until early stopping is executed
# Out:
# WARNING:tensorflow:From /Users/toby/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Train on 74 samples, validate on 8 samples
# Epoch 1/100
# 74/74 [==============================] - 1s 18ms/step - loss: 1.0004 - val_loss: 0.9328
# Epoch 2/100
# 74/74 [==============================] - 0s 934us/step - loss: 0.7965 - val_loss: 0.7275
# Epoch 3/100
# 74/74 [==============================] - 0s 997us/step - loss: 0.5574 - val_loss: 0.5357
# Epoch 4/100
# 74/74 [==============================] - 0s 1ms/step - loss: 0.3743 - val_loss: 0.3783
# Epoch 5/100
# 74/74 [==============================] - 0s 1ms/step - loss: 0.2445 - val_loss: 0.2280
# Epoch 6/100
# 74/74 [==============================] - 0s 1ms/step - loss: 0.1447 - val_loss: 0.1769
# Epoch 7/100
# 74/74 [==============================] - 0s 1ms/step - loss: 0.0241 - val_loss: 0.1440
# Epoch 8/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.0760 - val_loss: 0.1223
# Epoch 9/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.1531 - val_loss: -0.0500
# Epoch 10/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.2021 - val_loss: 0.0177
# Epoch 11/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.2647 - val_loss: -0.1059
# Epoch 12/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.2891 - val_loss: -0.1464
# Epoch 13/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.2857 - val_loss: -0.0915
# Epoch 14/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.3355 - val_loss: -0.1703
# Epoch 15/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.3624 - val_loss: -0.0644
# Epoch 16/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.3205 - val_loss: -0.2263
# Epoch 17/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.3841 - val_loss: -0.2423
# Epoch 18/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.4785 - val_loss: -0.2450
# Epoch 19/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.5947 - val_loss: -0.1560
# Epoch 20/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.6095 - val_loss: -0.3456
# Epoch 21/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.5958 - val_loss: -0.4504
# Epoch 22/100
# 74/74 [==============================] - 0s 3ms/step - loss: -0.5643 - val_loss: -0.1924
# Epoch 23/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.6470 - val_loss: -0.2853
# Epoch 24/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.6821 - val_loss: -0.4037
# Epoch 25/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.6526 - val_loss: -0.2998
# Epoch 26/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.5347 - val_loss: -0.5542
# Epoch 27/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.6518 - val_loss: -0.4003
# Epoch 28/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.6866 - val_loss: -0.5458
# Epoch 29/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.7061 - val_loss: -0.5252
# Epoch 30/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.5996 - val_loss: -0.5406
# Epoch 31/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.6586 - val_loss: -0.3425
# Epoch 32/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.7627 - val_loss: -0.6000
# Epoch 33/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.8252 - val_loss: -0.6486
# Epoch 34/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.8731 - val_loss: -0.5963
# Epoch 35/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.9058 - val_loss: -0.7180
# Epoch 36/100
# 74/74 [==============================] - 0s 1ms/step - loss: -0.9580 - val_loss: -0.4738
# Epoch 37/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.9044 - val_loss: -0.7880
# Epoch 38/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.9442 - val_loss: -0.6583
# Epoch 39/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.8820 - val_loss: -0.5922
# Epoch 40/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.8979 - val_loss: -0.6678
# Epoch 41/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.0663 - val_loss: -0.7006
# Epoch 42/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.0274 - val_loss: -0.4355
# Epoch 43/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.9565 - val_loss: -0.6837
# Epoch 44/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.0220 - val_loss: -0.7002
# Epoch 45/100
# 74/74 [==============================] - 0s 2ms/step - loss: -0.9917 - val_loss: -0.5857
# Epoch 46/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.0000 - val_loss: -0.6023
# Epoch 47/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.0526 - val_loss: -0.5819
# Epoch 48/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.1066 - val_loss: -0.6437
# Epoch 49/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.0980 - val_loss: -0.5125
# Epoch 50/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.1208 - val_loss: -0.3361
# Epoch 51/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.0366 - val_loss: -0.5464
# Epoch 52/100
# 74/74 [==============================] - 0s 990us/step - loss: -1.0637 - val_loss: -0.7826
# Epoch 53/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.1398 - val_loss: -0.7173
# Epoch 54/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.1706 - val_loss: -0.4763
# Epoch 55/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.1340 - val_loss: -0.5600
# Epoch 56/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.1120 - val_loss: -0.5033
# Epoch 57/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.2528 - val_loss: -0.6674
# Epoch 58/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.2118 - val_loss: -0.8277
# Epoch 59/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.1862 - val_loss: -0.8412
# Epoch 60/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.2221 - val_loss: -0.5729
# Epoch 61/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.1820 - val_loss: -0.7891
# Epoch 62/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.2272 - val_loss: -0.5532
# Epoch 63/100
# 74/74 [==============================] - 0s 3ms/step - loss: -1.2554 - val_loss: -0.6726
# Epoch 64/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.2351 - val_loss: -0.6098
# Epoch 65/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.2591 - val_loss: -0.6247
# Epoch 66/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.2625 - val_loss: -0.9124
# Epoch 67/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.2118 - val_loss: -0.6590
# Epoch 68/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3235 - val_loss: -0.9437
# Epoch 69/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3328 - val_loss: -0.5526
# Epoch 70/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3654 - val_loss: -0.8729
# Epoch 71/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3286 - val_loss: -0.7037
# Epoch 72/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4156 - val_loss: -0.8672
# Epoch 73/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3663 - val_loss: -0.8364
# Epoch 74/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3211 - val_loss: -0.6688
# Epoch 75/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3399 - val_loss: -0.8011
# Epoch 76/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4029 - val_loss: -0.9611
# Epoch 77/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4642 - val_loss: -0.8981
# Epoch 78/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4233 - val_loss: -0.9234
# Epoch 79/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.4137 - val_loss: -0.8580
# Epoch 80/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4534 - val_loss: -0.8008
# Epoch 81/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4276 - val_loss: -1.0916
# Epoch 82/100
# 74/74 [==============================] - 0s 915us/step - loss: -1.4663 - val_loss: -0.8423
# Epoch 83/100
# 74/74 [==============================] - 0s 939us/step - loss: -1.4303 - val_loss: -0.6414
# Epoch 84/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3645 - val_loss: -0.5769
# Epoch 85/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.3819 - val_loss: -0.6431
# Epoch 86/100
# 74/74 [==============================] - 0s 965us/step - loss: -1.4126 - val_loss: -0.8179
# Epoch 87/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.4457 - val_loss: -0.5567
# Epoch 88/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.5387 - val_loss: -0.6870
# Epoch 89/100
# 74/74 [==============================] - 0s 3ms/step - loss: -1.5582 - val_loss: -0.8903
# Epoch 90/100
# 74/74 [==============================] - 0s 3ms/step - loss: -1.5388 - val_loss: -0.6733
# Epoch 91/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.5440 - val_loss: -0.9441
# Epoch 92/100
# 74/74 [==============================] - 0s 3ms/step - loss: -1.5281 - val_loss: -0.8819
# Epoch 93/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.5532 - val_loss: -0.6895
# Epoch 94/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.4536 - val_loss: -0.7232
# Epoch 95/100
# 74/74 [==============================] - 0s 3ms/step - loss: -1.5803 - val_loss: -0.8900
# Epoch 96/100
# 74/74 [==============================] - 0s 3ms/step - loss: -1.6031 - val_loss: -1.0237
# Epoch 97/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.6002 - val_loss: -1.0553
# Epoch 98/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.5844 - val_loss: -0.9371
# Epoch 99/100
# 74/74 [==============================] - 0s 2ms/step - loss: -1.6196 - val_loss: -0.8887
# Epoch 100/100
# 74/74 [==============================] - 0s 1ms/step - loss: -1.5302 - val_loss: -0.8530

# %%
plt.figure(figsize=(10,5))
plt.plot(forecaster.history.epoch, forecaster.history.history['loss'], 'r')
plt.plot(forecaster.history.epoch, forecaster.history.history['val_loss'], 'blue') 
plt.xlabel('Epoch number')
plt.ylabel('Loss')
plt.legend(['loss', 'validation loss'])

# %% [markdown]
# Using the trained model, we can make predictions for our dataset. The horizon parameter of the forecaster will determine how far into the future our predictions will reach. The forecast predictions are produced such that the forecasted values are extending the input time series. For example, if we use the training data here as input, the forecaster predictions will be made for time steps after the training data time steps.

# %%
predictions = forecaster.predict(data=train_data, n_samples=1000)  # Draw 100 samples for predictions

# %% [markdown]
# Let's get the test set accuracy for different metrics from model

# %%
print('MSE: {}'.format(round(metrics.mse(predictions['mean'], test_data), 2)))
print('MAPE: {}%'.format(round(metrics.mape(predictions['mean'], test_data), 2)))
print('SMAPE: {}%'.format(round(metrics.smape(predictions['mean'], test_data), 2)))
# Out:
# MSE: 1133064680.39
# MAPE: 13.94%
# SMAPE: 14.49%

# %%
ncols = 5
fig, axes = plt.subplots(nrows=26//ncols+1, ncols=ncols, sharex=True, sharey=True, figsize=(12, 9))
for ax, ya, yl, yu, title in zip(axes.flat, 
                             test_data[0,:,:].T,
                             predictions['lower_quantile'][0,:,:].T,
                             predictions['upper_quantile'][0,:,:].T,
                             range(1,26+1)):
    ax.plot(yl, 'g-')
    ax.plot(yu, 'g-')
    ax.plot(ya, 'r-')
    ax.set_title(title)

plt.tight_layout()

# %% [markdown]
# ## Data preparation for multiple univariate time series

# %% [markdown]
# Now we will train a forecaster that understands the data as 26 examples for univariate time series. This fact is illustrated in the figure below by coloring each time series differently.

# %%
# Load the data from file
filename = 'timeseries_data.csv'
df = read_table(filename, sep=',')

# Prepare the data set
data = df.values.T
data = np.expand_dims(data, -1)

# Let's make the algorithms life harder by randomly cutting of up to the first 20 data points
new_data = []
for time_series in data:
    cutoff = np.random.randint(20)
    new_data.append(time_series[cutoff:,:])
data = np.array(new_data)

# We just need a small holdout dataset for evaluation purposes
holdout = 9
train_data, test_data = [], []
for time_series in data:
    train_data.append(time_series[:-holdout,:])
    test_data.append(time_series[-holdout:,:])
train_data = np.array(train_data)
test_data = np.array(test_data)
    
# Plot the dataset
plt.figure(figsize=(10,5))
for time_series in data:
    plt.plot(time_series[::-1])
plt.xlabel('Month before beginning')
plt.ylabel('Quantity')
# Out:
# Text(0,0.5,'Quantity')

# %% [markdown]
# For reasons of comparibility, we use the same forecaster architecture as above.

# %%
forecaster = Forecaster(
    topology,
    lag=20,  # This is the number of time steps used to predict the future for each data point
    horizon=9,  # This is how many time steps into the future we want to produce
    optimizer='nadam',  # Which optimizer the forecaster is using
    loss='heteroscedastic_gaussian',  # This specifies a custom log-likelihood loss
    lr=0.001,  # This is the learning rate for the optimizer
    dropout_rate=0.1,  # The dropout rate refers to the MC dropout rate applied after each layer
    max_epochs=1000  # Maximum number of epochs that the optimizer will perform
)

# %%
forecaster.fit(train_data, val_frac=0.10, patience=50)  # patience is the number of epochs to wait until early stopping is executed
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-69bcd2e1a1e1> in <module>()
# ----> 1 forecaster.fit(train_data, val_frac=0.10, patience=50)  # patience is the number of epochs to wait until early stopping is executed
#
# ~/cdna/deep4cast/deep4cast/forecasters.py in fit(self, data, targets, val_frac, patience, verbose)
#     157             validation_data=(X_val, y_val),
#     158             callbacks=[es],
# --> 159             verbose=verbose
#     160         )
#     161
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/deep_forecast/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10,5))
plt.plot(forecaster.history.epoch, forecaster.history.history['loss'], 'r')
plt.plot(forecaster.history.epoch, forecaster.history.history['val_loss'], 'blue') 
plt.xlabel('Epoch number')
plt.ylabel('Loss')
plt.legend(['loss', 'validation loss'])

# %% [markdown]
# Again, we can generate predictions see what we get :).

# %%
predictions = forecaster.predict(data=train_data, n_samples=100)  # Just as before, we produce predictions

# %%
print('MSE: {}'.format(round(metrics.mse(predictions['mean'], test_data), 2)))
print('MAPE: {}%'.format(round(metrics.mape(predictions['mean'], test_data), 2)))
print('SMAPE: {}%'.format(round(metrics.smape(predictions['mean'], test_data), 2)))

# %%
ncols = 5
fig, axes = plt.subplots(nrows=26//ncols+1, ncols=ncols, sharex=True, sharey=True, figsize=(12, 9))
for ax, ya, yp, title in zip(axes.flat, 
                             test_data[:,:,0],
                             np.swapaxes(predictions['samples'][:,:,:,0],0,1),
                             range(1,26+1)):
    for ys in yp:
        ax.plot(ys, 'g-', alpha=0.05)
    ax.plot(ya, 'r-')
    ax.set_title(title)

plt.tight_layout()
