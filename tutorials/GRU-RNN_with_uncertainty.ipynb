# %% [markdown]
# # GRU with uncertainty tutorial

# %% [markdown]
# In this tutorial, we show how to quickly set up and train an RNN regression model with the deep4cast package. The goal is to show you how to handle the package interface and inspect the model object after training. The example data constitutes of a monthly 26-dimensional multivariate time series.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_table

from deep4cast.forecasters import Forecaster
import deep4cast.metrics as metrics

# %matplotlib inline

# Fix random number seed for reproducibility
np.random.seed(3)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data preparation for single multivariate time series

# %% [markdown]
# Before we can fit a model we first have to load, clean, and prepare our dataset so that the model can accept it. The data is prepared such that the forecaster view the data as a single example of a 26-dimensional time series. In another example, further down, we will train a forecaster that understands the data as 26 examples for univariate time series.

# %%
# Load the data from file
filename = 'timeseries_data.csv'
df = read_table(filename, sep=',')

# Prepare the data set
data = df.values
data = np.expand_dims(data, 0)

# We just need a small holdout dataset for evaluation purposes
holdout = 9
train_data = data[:,:-9,:]
test_data = data[:,-9:,:]

# Plot the dataset
plt.figure(figsize=(10,5))
plt.plot(data[0,::-1,:], 'k')
plt.xlabel('Month before beginning')
plt.ylabel('Quantity')
# Out:
# Text(0,0.5,'Quantity')

# %%
test_data.shape
# Out:
# (1, 9, 26)

# %% [markdown]
# ## Recurrent Neural Network Forecaster using GRU cells

# %% [markdown]
# Now that we have cleaned and prepared our dataset, we can proceed to fit a regression model. Here, we choose the LSTM-GRU, with windowed training intput.

# %%
topology = [
    {
        'meta': {
            'layer_type': 'GRU', 
            'layer_id': 'gru1', 
            'parent_ids': ['input']
        },
        'params': {
            'units': 128, 
            'activation': 'relu',
            'return_sequences': True
        }
    },
    {
        'meta': {
            'layer_type': 'GRU', 
            'layer_id': 'gru2', 
            'parent_ids': ['gru1']
        },
        'params': {
            'units': 128, 
            'activation': 'relu',
            'return_sequences': False
        }
    }
]

# %% [markdown]
# Now, we can set up the forecaster object using arguments to specify lookbacks and forecasting horizons, as well as optimizer parameters. The default loss of the forecaster is the mean-squared error loss.

# %%
forecaster = Forecaster(
    topology,
    lag=20,  # This is the number of time steps used to predict the future for each data point
    horizon=9,  # This is how many time steps into the future we want to produce
    optimizer='nadam',  # Which optimizer the forecaster is using
    loss='heteroscedastic_gaussian',  # This specifies a custom log-likelihood loss
    lr=0.001,  # This is the learning rate for the optimizer
    dropout_rate=0.2,  # The dropout rate refers to the MC dropout rate applied after each layer
    max_epochs=1000  # Maximum number of epochs that the optimizer will perform
)

# %% [markdown]
# We can now fit the forecaster and unspect the training and validation losses. The plot below show the training and validation loss for each epoch of training. By default, the forecaster uses Keras' early stopping callback to stopp training when the validation set error increases. The default holdout from the input data used for validation is 10% of the data.

# %%
forecaster.fit(train_data, val_frac=0.10, patience=50)  # patience is the number of epochs to wait until early stopping is executed

# %%
plt.figure(figsize=(10,5))
plt.plot(forecaster.history.epoch, forecaster.history.history['loss'], 'r')
plt.plot(forecaster.history.epoch, forecaster.history.history['val_loss'], 'blue') 
plt.xlabel('Epoch number')
plt.ylabel('Loss')
plt.legend(['loss', 'validation loss'])

# %% [markdown]
# Using the trained model, we can make predictions for our dataset. The horizon parameter of the forecaster will determine how far into the future our predictions will reach. The forecast predictions are produced such that the forecasted values are extending the input time series. For example, if we use the training data here as input, the forecaster predictions will be made for time steps after the training data time steps.

# %%
predictions = forecaster.predict(data=train_data, n_samples=100)  # Draw 100 samples for predictions

# %% [markdown]
# Let's get the test set accuracy for different metrics from model

# %%
print('MSE: {}'.format(round(metrics.mse(test_data, predictions['mean']), 2)))
print('MAPE: {}%'.format(round(metrics.mape(test_data, predictions['mean']), 2)))
print('SMAPE: {}%'.format(round(metrics.smape(test_data, predictions['mean']), 2)))
# Out:
# MSE: 1024256239.29
# MAPE: 17.84%
# SMAPE: 17.35%

# %%
ncols = 5
fig, axes = plt.subplots(nrows=26//ncols+1, ncols=ncols, sharex=True, sharey=True, figsize=(12, 9))
for ax, ya, yp, title in zip(axes.flat, 
                             test_data[0,:,:].T,
                             predictions['samples'].T,
                             range(1,26+1)):
    for ys in yp.T:
        ax.plot(ys[0,:], 'g-', alpha=0.05)
    ax.plot(ya, 'r-')
    ax.set_title(title)

plt.tight_layout()

# %% [markdown]
# ## Data preparation for multiple univariate time series

# %% [markdown]
# Now we will train a forecaster that understands the data as 26 examples for univariate time series. This fact is illustrated in the figure below by coloring each time series differently.

# %%
# Load the data from file
filename = 'timeseries_data.csv'
df = read_table(filename, sep=',')

# Prepare the data set
data = df.values.T
data = np.expand_dims(data, -1)

# Let's make the algorithms life harder by randomly cutting of up to the first 20 data points
new_data = []
for time_series in enumerate(data):
    cutoff = np.random.randint(20)
    new_data.append(time_series[cutoff:,:])
data = np.array(new_data)

# We just need a small holdout dataset for evaluation purposes
holdout = 9
train_data, test_data = [], []
for time_series in data:
    train_data.append(time_series[:-holdout,:])
    test_data.append(time_series[-holdout:,:])
train_data = np.array(train_data)
test_data = np.array(test_data)
    
# Plot the dataset
plt.figure(figsize=(10,5))
for time_series in data:
    plt.plot(time_series[::-1])
plt.xlabel('Month before beginning')
plt.ylabel('Quantity')
# Out:
# Text(0,0.5,'Quantity')

# %% [markdown]
# For reasons of comparibility, we use the same forecaster architecture as above.

# %%
forecaster = Forecaster(
    topology,
    lag=20,  # This is the number of time steps used to predict the future for each data point
    horizon=9,  # This is how many time steps into the future we want to produce
    optimizer='nadam',  # Which optimizer the forecaster is using
    loss='heteroscedastic_gaussian',  # This specifies a custom log-likelihood loss
    lr=0.001,  # This is the learning rate for the optimizer
    dropout_rate=0.2,  # The dropout rate refers to the MC dropout rate applied after each layer
    max_epochs=1000  # Maximum number of epochs that the optimizer will perform
)

# %%
forecaster.fit(train_data, val_frac=0.10, patience=50)  # patience is the number of epochs to wait until early stopping is executed
# Out:
# Train on 119 samples, validate on 13 samples
# Epoch 1/1000
#  - 2s - loss: 1.0096 - val_loss: 0.9030
# Epoch 2/1000
#  - 1s - loss: 0.9462 - val_loss: 0.8356
# Epoch 3/1000
#  - 1s - loss: 0.7917 - val_loss: 0.7895
# Epoch 4/1000
#  - 1s - loss: 0.7340 - val_loss: 0.7778
# Epoch 5/1000
#  - 1s - loss: 0.7255 - val_loss: 0.8276
# Epoch 6/1000
#  - 1s - loss: 0.7164 - val_loss: 0.7860
# Epoch 7/1000
#  - 1s - loss: 0.6812 - val_loss: 0.8253
# Epoch 8/1000
#  - 1s - loss: 0.6611 - val_loss: 0.8002
# Epoch 9/1000
#  - 1s - loss: 0.6312 - val_loss: 0.7079
# Epoch 10/1000
#  - 1s - loss: 0.6008 - val_loss: 0.7611
# Epoch 11/1000
#  - 1s - loss: 0.5411 - val_loss: 0.6087
# Epoch 12/1000
#  - 1s - loss: 0.5721 - val_loss: 0.6945
# Epoch 13/1000
#  - 1s - loss: 0.5253 - val_loss: 0.5216
# Epoch 14/1000
#  - 1s - loss: 0.4641 - val_loss: 0.4940
# Epoch 15/1000
#  - 1s - loss: 0.3949 - val_loss: 0.4784
# Epoch 16/1000
#  - 1s - loss: 0.3297 - val_loss: 0.6624
# Epoch 17/1000
#  - 1s - loss: 0.4096 - val_loss: 0.3022
# Epoch 18/1000
#  - 1s - loss: 0.2932 - val_loss: 0.7156
# Epoch 19/1000
#  - 1s - loss: 0.2498 - val_loss: 0.2646
# Epoch 20/1000
#  - 1s - loss: 0.1610 - val_loss: 0.3007
# Epoch 21/1000
#  - 1s - loss: 0.0599 - val_loss: 0.3982
# Epoch 22/1000
#  - 1s - loss: -4.5363e-02 - val_loss: 0.0824
# Epoch 23/1000
#  - 1s - loss: -8.2945e-02 - val_loss: 0.2613
# Epoch 24/1000
#  - 1s - loss: -3.0761e-03 - val_loss: -7.7239e-02
# Epoch 25/1000
#  - 1s - loss: -1.7833e-01 - val_loss: 0.0563
# Epoch 26/1000
#  - 1s - loss: -2.2437e-01 - val_loss: -3.6503e-02
# Epoch 27/1000
#  - 1s - loss: 0.0249 - val_loss: 0.0074
# Epoch 28/1000
#  - 1s - loss: -2.0244e-02 - val_loss: 0.0189
# Epoch 29/1000
#  - 1s - loss: -2.0125e-01 - val_loss: -3.4986e-02
# Epoch 30/1000
#  - 1s - loss: -2.8453e-01 - val_loss: -1.0982e-01
# Epoch 31/1000
#  - 1s - loss: -4.0100e-01 - val_loss: -1.6550e-01
# Epoch 32/1000
#  - 1s - loss: -4.9949e-01 - val_loss: -2.5591e-01
# Epoch 33/1000
#  - 1s - loss: -2.7728e-01 - val_loss: -5.9071e-02
# Epoch 34/1000
#  - 1s - loss: -2.8252e-01 - val_loss: -3.4615e-01
# Epoch 35/1000
#  - 1s - loss: -4.2101e-01 - val_loss: -3.7462e-01
# Epoch 36/1000
#  - 1s - loss: -5.2926e-01 - val_loss: -5.8758e-01
# Epoch 37/1000
#  - 1s - loss: -6.7468e-01 - val_loss: -4.5120e-01
# Epoch 38/1000
#  - 1s - loss: -5.0795e-01 - val_loss: -1.9078e-01
# Epoch 39/1000
#  - 1s - loss: -7.0517e-01 - val_loss: -3.5685e-01
# Epoch 40/1000
#  - 1s - loss: -6.7958e-01 - val_loss: -6.9993e-01
# Epoch 41/1000
#  - 1s - loss: -7.0723e-01 - val_loss: -5.7244e-01
# Epoch 42/1000
#  - 1s - loss: -7.9058e-01 - val_loss: -6.2650e-01
# Epoch 43/1000
#  - 1s - loss: -7.9519e-01 - val_loss: -5.8052e-01
# Epoch 44/1000
#  - 1s - loss: -8.0589e-01 - val_loss: -6.5809e-01
# Epoch 45/1000
#  - 1s - loss: -9.3345e-01 - val_loss: -6.8520e-01
# Epoch 46/1000
#  - 1s - loss: -9.1517e-01 - val_loss: -7.2141e-01
# Epoch 47/1000
#  - 1s - loss: -9.1274e-01 - val_loss: -2.7133e-01
# Epoch 48/1000
#  - 1s - loss: -9.8763e-01 - val_loss: -5.5284e-01
# Epoch 49/1000
#  - 1s - loss: -1.0231e+00 - val_loss: -7.9161e-01
# Epoch 50/1000
#  - 1s - loss: -1.0731e+00 - val_loss: -3.7315e-01
# Epoch 51/1000
#  - 1s - loss: -9.7616e-01 - val_loss: -6.4796e-01
# Epoch 52/1000
#  - 1s - loss: -9.0172e-01 - val_loss: -3.4740e-01
# Epoch 53/1000
#  - 1s - loss: -9.3278e-01 - val_loss: -8.6979e-01
# Epoch 54/1000
#  - 1s - loss: -1.1425e+00 - val_loss: -7.9422e-01
# Epoch 55/1000
#  - 1s - loss: -1.1908e+00 - val_loss: -5.6797e-01
# Epoch 56/1000
#  - 1s - loss: -1.2271e+00 - val_loss: -8.7504e-01
# Epoch 57/1000
#  - 1s - loss: -1.3057e+00 - val_loss: -2.2900e-01
# Epoch 58/1000
#  - 1s - loss: -1.0925e+00 - val_loss: -8.7523e-01
# Epoch 59/1000
#  - 1s - loss: -1.2262e+00 - val_loss: -1.0175e+00
# Epoch 60/1000
#  - 1s - loss: -1.2429e+00 - val_loss: -6.3074e-01
# Epoch 61/1000
#  - 1s - loss: -1.2715e+00 - val_loss: -6.8488e-01
# Epoch 62/1000
#  - 1s - loss: -1.3527e+00 - val_loss: -1.0745e+00
# Epoch 63/1000
#  - 1s - loss: -1.2712e+00 - val_loss: -1.2120e+00
# Epoch 64/1000
#  - 1s - loss: -1.0402e+00 - val_loss: -8.9362e-01
# Epoch 65/1000
#  - 1s - loss: -1.3375e+00 - val_loss: -9.5322e-01
# Epoch 66/1000
#  - 1s - loss: -1.3511e+00 - val_loss: -1.2008e+00
# Epoch 67/1000
#  - 1s - loss: -1.3889e+00 - val_loss: -1.0947e+00
# Epoch 68/1000
#  - 1s - loss: -1.4760e+00 - val_loss: -8.1773e-01
# Epoch 69/1000
#  - 1s - loss: -1.3236e+00 - val_loss: -3.1551e-01
# Epoch 70/1000
#  - 1s - loss: -1.3993e+00 - val_loss: -8.3165e-01
# Epoch 71/1000
#  - 1s - loss: -1.5069e+00 - val_loss: -1.1195e+00
# Epoch 72/1000
#  - 1s - loss: -1.5182e+00 - val_loss: -6.6962e-01
# Epoch 73/1000
#  - 1s - loss: -1.4339e+00 - val_loss: -9.9955e-01

# %%
plt.figure(figsize=(10,5))
plt.plot(forecaster.history.epoch, forecaster.history.history['loss'], 'r')
plt.plot(forecaster.history.epoch, forecaster.history.history['val_loss'], 'blue') 
plt.xlabel('Epoch number')
plt.ylabel('Loss')
plt.legend(['loss', 'validation loss'])

# %% [markdown]
# Again, we can generate predictions see what we get :).

# %%
predictions = forecaster.predict(data=train_data, n_samples=100)  # Just as before, we produce predictions

# %%
print('MSE: {}'.format(round(metrics.mse(test_data, predictions['mean']), 2)))
print('MAPE: {}%'.format(round(metrics.mape(test_data, predictions['mean']), 2)))
print('SMAPE: {}%'.format(round(metrics.smape(test_data, predictions['mean']), 2)))
# Out:
# MSE: 662013265.9
# MAPE: 26.72%
# SMAPE: 24.03%

# %%
ncols = 5
fig, axes = plt.subplots(nrows=26//ncols+1, ncols=ncols, sharex=True, sharey=True, figsize=(12, 9))
for ax, ya, yp, title in zip(axes.flat, 
                             test_data[:,:,0],
                             np.swapaxes(predictions['samples'][:,:,:,0],0,1),
                             range(1,26+1)):
    for ys in yp:
        ax.plot(ys, 'g-', alpha=0.05)
    ax.plot(ya, 'r-')
    ax.set_title(title)

plt.tight_layout()
